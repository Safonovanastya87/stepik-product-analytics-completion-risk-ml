# %%
if (!require(readr)) install.packages("readr")
if (!require(dplyr)) install.packages("dplyr")
if (!require(lubridate)) install.packages("lubridate")
if (!require(tidyr)) install.packages("tidyr")
if (!require(tidyr)) install.packages("ggplot2")
if (!require(corrplot)) install.packages("corrplot")
if (!require(caret)) install.packages("caret")
if (!require(rlang)) install.packages("rlang")
if (!require(xgboost)) install.packages("xgboost")
if (!require(car)) install.packages("car")
if (!require(knitr)) install.packages("knitr")
if (!require(xgboost)) install.packages("xgboost")
if (!require(MLmetrics)) install.packages("MLmetrics")
# Out:
# Загрузка требуемого пакета: readr
#
# Warning message:
# "пакет 'readr' был собран под R версии 4.4.3"
# Загрузка требуемого пакета: dplyr
#
#
# Присоединяю пакет: 'dplyr'
#
#
# Следующие объекты скрыты от 'package:stats':
#
#     filter, lag
#
#
# Следующие объекты скрыты от 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Загрузка требуемого пакета: lubridate
#
# Warning message:
# "пакет 'lubridate' был собран под R версии 4.4.3"
#
# Присоединяю пакет: 'lubridate'
#
#
# Следующие объекты скрыты от 'package:base':
#
#     date, intersect, setdiff, union
#
#
# Загрузка требуемого пакета: tidyr
#
# Загрузка требуемого пакета: corrplot
#
# Warning message:
# "пакет 'corrplot' был собран под R версии 4.4.3"
# corrplot 0.95 loaded
#
# Загрузка требуемого пакета: caret
#
# Warning message:
# "пакет 'caret' был собран под R версии 4.4.3"
# Загрузка требуемого пакета: ggplot2
#
# Warning message:
# "пакет 'ggplot2' был собран под R версии 4.4.3"
# ...

# %%
library(readr)
library(dplyr)
library(lubridate)
library(tidyr)
library(ggplot2)
library(corrplot)
library(caret)
library(xgboost)
library(rlang)
library(car)
library(knitr)
library(xgboost)
library(MLmetrics)

# %% [markdown]
# ## Summary:
# Data Cleaning
#
# EDA (только базовая часть)
#
# Feature Engineering
#
# GLM
#
# XGBoost
#
# Interpretation
#
# Recommendations based on models

# %% [markdown]
#  ## Data Loading and Overviewing

# %%
events_data <- read_csv("C:\\Users\\safon\\Documents\\data_stepic\\event_data_train.csv")
submissions_data <- read_csv("C:\\Users\\safon\\Documents\\data_stepic\\submissions_data_train.csv")
# Out:
# Rows: 3480703 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): action
# dbl (3): step_id, timestamp, user_id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 509104 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): submission_status
# dbl (3): step_id, timestamp, user_id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
cat("events_data size:", format(object.size(events_data), units = "MB"), "\n")
cat("submissions_data size:", format(object.size(submissions_data), units = "MB"), "\n")
# Out:
# events_data size: 106.2 Mb
# submissions_data size: 15.5 Mb

# %%
head(events_data,20)
# Out:
#    step_id timestamp  action          user_id
# 1  32815   1434340848 viewed          17632
# 2  32815   1434340848 passed          17632
# 3  32815   1434340848 discovered      17632
# 4  32811   1434340895 discovered      17632
# 5  32811   1434340895 viewed          17632
# 6  32811   1434340895 passed          17632
# 7  32929   1434340921 discovered      17632
# 8  32929   1434340921 viewed          17632
# 9  32929   1434340939 started_attempt 17632
# 10 32929   1434340944 passed          17632
# 11 32814   1434340950 viewed          17632
# 12 32814   1434340950 discovered      17632
# 13 32814   1434340950 passed          17632
# 14 32812   1434340991 viewed          17632
# 15 32812   1434340991 discovered      17632
# 16 32812   1434341016 started_attempt 17632
# 17 32812   1434341039 passed          17632
# 18 32816   1434341044 viewed          17632
# 19 32816   1434341044 passed          17632
# 20 32816   1434341044 discovered      17632

# %%
events_data %>% sample_n(10)
# Out:
#    step_id timestamp  action          user_id
# 1  33376   1493121064 discovered      16831
# 2  32206   1462443381 viewed          17653
# 3  31983   1459430956 started_attempt 25544
# 4  32191   1463986524 viewed          11770
# 5  32197   1524085649 discovered      22244
# 6  31959   1435485983 viewed          13071
# 7  32927   1472172214 viewed          21030
# 8  32177   1478638432 viewed          14054
# 9  32190   1513073496 viewed          16226
# 10 33685   1437411505 viewed           9253

# %%
glimpse(events_data)
# Out:
# Rows: 3,480,703
# Columns: 4
# $ step_id   <dbl> 32815, 32815, 32815, 32811, 32811, 32811, 32929, 32929, 3292…
# $ timestamp <dbl> 1434340848, 1434340848, 1434340848, 1434340895, 1434340895, …
# $ action    <chr> "viewed", "passed", "discovered", "discovered", "viewed", "p…
# $ user_id   <dbl> 17632, 17632, 17632, 17632, 17632, 17632, 17632, 17632, 1763…

# %%
unique(events_data$action)
# Out:
# [1] "viewed"          "passed"          "discovered"      "started_attempt"

# %%
events_data %>% count(action) %>% mutate(p = n / sum(n))
# Out:
#   action          n       p
# 1 discovered       689495 0.19809073
# 2 passed           650331 0.18683898
# 3 started_attempt  310047 0.08907597
# 4 viewed          1830830 0.52599432

# %%
summary(events_data)
# Out:
#     step_id         timestamp            action             user_id
#  Min.   : 30456   Min.   :1.434e+09   Length:3480703     Min.   :    1
#  1st Qu.: 32179   1st Qu.:1.450e+09   Class :character   1st Qu.: 6642
#  Median : 32929   Median :1.484e+09   Mode  :character   Median :13208
#  Mean   : 34874   Mean   :1.480e+09                      Mean   :13315
#  3rd Qu.: 33481   3rd Qu.:1.508e+09                      3rd Qu.:20144
#  Max.   :158433   Max.   :1.527e+09                      Max.   :26798

# %% [markdown]
# ### Note on step_id structure:
# Step identifiers on the Stepik platform are global and not sequential within a course.
# Large gaps and high numeric values (e.g., 150k+) are normal.
# Step IDs are treated as categorical identifiers without semantic meaning.

# %%
events_data %>%
    summarise(across(everything(),n_distinct))
# Out:
#   step_id timestamp action user_id
# 1 198     2196932   4      19234

# %%
colSums(is.na(events_data))
# Out:
#   step_id timestamp    action   user_id
#         0         0         0         0

# %%
sum(duplicated(events_data))
# Out:
# [1] 2333

# %%
head(submissions_data)
# Out:
#   step_id timestamp  submission_status user_id
# 1 31971   1434349275 correct           15853
# 2 31972   1434348300 correct           15853
# 3 31972   1478852149 wrong             15853
# 4 31972   1478852164 correct           15853
# 5 31976   1434348123 wrong             15853
# 6 31976   1434348188 correct           15853

# %%
submissions_data %>% sample_n(10)
# Out:
#    step_id timestamp  submission_status user_id
# 1  31977   1487191517 wrong             21856
# 2  33994   1496599994 correct           16933
# 3  32173   1496181955 correct            6378
# 4  32810   1460722322 correct           13487
# 5  32075   1499676775 wrong              2184
# 6  33713   1489405720 wrong             18279
# 7  33079   1508012983 wrong             18863
# 8  33480   1476010779 correct            8325
# 9  32198   1435000280 wrong             10884
# 10 31978   1462191036 correct           18851

# %%
glimpse(submissions_data)
# Out:
# Rows: 509,104
# Columns: 4
# $ step_id           <dbl> 31971, 31972, 31972, 31972, 31976, 31976, 31976, 319…
# $ timestamp         <dbl> 1434349275, 1434348300, 1478852149, 1478852164, 1434…
# $ submission_status <chr> "correct", "correct", "wrong", "correct", "wrong", "…
# $ user_id           <dbl> 15853, 15853, 15853, 15853, 15853, 15853, 15853, 158…

# %%
unique(submissions_data$submission_status)
# Out:
# [1] "correct" "wrong"

# %%
submissions_data %>% count(submission_status) %>% mutate(p = n/sum(n))
# Out:
#   submission_status n      p
# 1 correct           222705 0.437445
# 2 wrong             286399 0.562555

# %%
summary(submissions_data)
# Out:
#     step_id         timestamp         submission_status     user_id
#  Min.   : 31971   Min.   :1.434e+09   Length:509104      Min.   :    2
#  1st Qu.: 32031   1st Qu.:1.450e+09   Class :character   1st Qu.: 6431
#  Median : 32763   Median :1.484e+09   Mode  :character   Median :13082
#  Mean   : 33733   Mean   :1.481e+09                      Mean   :13199
#  3rd Qu.: 33481   3rd Qu.:1.508e+09                      3rd Qu.:19985
#  Max.   :120745   Max.   :1.527e+09                      Max.   :26798

# %% [markdown]
# ### Note on step_id:
# Step IDs on Stepik are global and not sequential within a course. Large numeric values and gaps are normal. The same pattern appears in both events and submissions, so step_id should be treated purely as a categorical identifier.

# %%
submissions_data %>%
    summarise(across(everything(),n_distinct))
# Out:
#   step_id timestamp submission_status user_id
# 1 76      504343    2                 9940

# %%
colSums(is.na(submissions_data))
# Out:
#           step_id         timestamp submission_status           user_id
#                 0                 0                 0                 0

# %%
sum(duplicated(submissions_data))
# Out:
# [1] 107

# %%
length(setdiff(unique(events_data$user_id), unique(submissions_data$user_id)))
length(setdiff(unique(events_data$step_id), unique(submissions_data$step_id)))
# Out:
# [1] 9294
# [1] 122

# %%
length(setdiff(unique(submissions_data$user_id), unique(events_data$user_id)))
length(setdiff(unique(submissions_data$step_id), unique(events_data$step_id)))
# Out:
# [1] 0
# [1] 0

# %% [markdown]
# ## EDA on Raw Event-Level Data

# %%
events_data <- events_data[!duplicated(events_data),]
submissions_data <- submissions_data[!duplicated(submissions_data),]

# %%
sum(duplicated(events_data))
sum(duplicated(submissions_data))
# Out:
# [1] 0
# [1] 0

# %%
events_data$timestamp_dt <- as_datetime(events_data$timestamp)
submissions_data$timestamp_dt <- as_datetime(submissions_data$timestamp)

# %%
summary(events_data$timestamp_dt)
summary(submissions_data$timestamp_dt)
# Out:
#                       Min.                    1st Qu.
# "2015-06-15 04:00:48.0000" "2015-12-16 06:23:43.2500"
#                     Median                       Mean
# "2017-01-08 18:23:00.0000" "2016-11-27 21:59:13.7051"
#                    3rd Qu.                       Max.
# "2017-10-13 10:38:29.5000" "2018-05-19 23:33:31.0000"
#                       Min.                    1st Qu.
# "2015-06-15 04:02:24.0000" "2015-12-13 00:52:11.0000"
#                     Median                       Mean
# "2017-01-13 21:33:35.0000" "2016-12-01 10:27:40.5671"
#                    3rd Qu.                       Max.
# "2017-10-18 12:12:03.0000" "2018-05-19 23:07:07.0000"

# %% [markdown]
# ## EDA вычислить сложные уроки

# %% [markdown]
# ## ------

# %%
passed_counts <- events_data %>%
  filter(action == "passed") %>%
  group_by(user_id, step_id) %>%
  summarise(passed_count = n(), .groups = "drop")

multiple_passed <- passed_counts %>%
  filter(passed_count > 1) %>%
        nrow()

multiple_passed
# Out:
# [1] 0

# %%
correct_counts <- submissions_data %>%
  filter(submission_status == "correct") %>%
  group_by(user_id, step_id) %>%
  summarise(correct_count = n(), .groups = "drop")

multiple_correct <- correct_counts %>%
  filter(correct_count > 1) %>%
        nrow()
        
multiple_correct
# Out:
# [1] 5066

# %%
comparison <- events_data %>%
  filter(action == "passed") %>%
  select(user_id, step_id, first_passed_time = timestamp_dt) %>%
  full_join(
    submissions_data %>%
      filter(submission_status == "correct") %>%
      group_by(user_id, step_id) %>%
      summarise(first_correct_time = min(timestamp_dt), .groups = "drop"),
    by = c("user_id", "step_id")
  ) %>%
  mutate(passed_before_correct = first_passed_time < first_correct_time)


comparison %>% filter(passed_before_correct)
# Out:
#      user_id step_id first_passed_time first_correct_time passed_before_correct

# %%
submissions_data %>%
    anti_join(
        events_data %>%
            filter(action == "started_attempt") %>%
            select(user_id, step_id),
        by = c("user_id", "step_id")
    ) %>%
        nrow()
# Out:
# [1] 6

# %%
events_data %>%
  arrange(user_id, timestamp_dt) %>%
  group_by(user_id) %>%
  filter(timestamp_dt < lag(timestamp_dt))
# Out:
#      step_id timestamp action user_id timestamp_dt

# %%
submissions_data %>%
  arrange(user_id, step_id, timestamp_dt) %>%
  group_by(user_id, step_id) %>%
  filter(timestamp_dt < lag(timestamp_dt))
# Out:
#      step_id timestamp submission_status user_id timestamp_dt

# %%
submissions_data %>%
  inner_join(events_data %>% 
               filter(action=="discovered") %>% 
               select(user_id, step_id, discovered_time = timestamp_dt),
             by=c("user_id","step_id")) %>%
  filter(timestamp_dt < discovered_time) %>%
    nrow()
# Out:
# [1] 203

# %% [markdown]
# ## EDA: Problematic Steps & User Activity Analysis
#
# A detailed analysis of problematic course steps is provided in a separate annex document due to its volume.

# %% [markdown]
# ## Preprocessing

# %%
user_level_data = data.frame(user_id = unique(events_data$user_id))

# %%
events_bounds <- events_data %>%
  group_by(user_id) %>%
  summarise(
    first_activity_events = min(timestamp_dt, na.rm = TRUE),
    last_activity_events  = max(timestamp_dt, na.rm = TRUE),
    .groups = "drop"
  )

submissions_bounds <- submissions_data %>%
  group_by(user_id) %>%
  summarise(
    first_activity_subm = min(timestamp_dt, na.rm = TRUE),
    last_activity_subm  = max(timestamp_dt, na.rm = TRUE),
    .groups = "drop"
  )

activity_bounds <- full_join(events_bounds, submissions_bounds, by = "user_id") %>%
  mutate(
    first_activity = pmin(first_activity_events, first_activity_subm, na.rm = TRUE),
    last_activity  = pmax(last_activity_events, last_activity_subm, na.rm = TRUE),
    activity_span_days = as.numeric(last_activity - first_activity, units = "days"),
    activity_span_days = ifelse(activity_span_days < 1, 1, activity_span_days)
  ) %>%
  select(user_id, first_activity, last_activity, activity_span_days)

user_level_data <- left_join(user_level_data, activity_bounds, by = "user_id")

# %%
activity_days <- bind_rows(
    events_data %>% select(user_id, timestamp_dt),
    submissions_data %>% select(user_id, timestamp_dt)
  ) %>%
  mutate(day = as_date(timestamp_dt)) %>%
  distinct(user_id, day)

active_days_df <- activity_days %>%
  count(user_id, name = "active_days")

median_gap_df <- activity_days %>%
  arrange(user_id, day) %>%
  group_by(user_id) %>%
  summarise(
    median_gap_days = if (n() >= 2) median(as.numeric(diff(day))) else 0,
    .groups = "drop"
  )

user_level_data <- user_level_data %>%
  left_join(active_days_df, by = "user_id") %>%
  left_join(median_gap_df, by = "user_id")

# %%
steps <- sort(unique(events_data$step_id))
step_score_vec <- rep(0, length(steps))

score <- list(
  `1` = c(3,14,15,18,19,22,30,31,32,33,38,39,40,47,49,53,54,55,56,57,
          62,64,65,68,73,74,76,80,81,82,83,95,100,104,108,109,111,
          122,123,131,133,138,139,140,141,147,148,149,155,156,157,
          161,162,163,169,170,172,177,185,186),

  `2` = c(41,63,94,99,113,114,115,125,132,179,189),

  `3` = c(126,180)
)

# Векторизация загрузки score
step_score_vec[unlist(score)] <- rep(names(score), lengths(score))

step_index <- match(events_data$step_id, steps)

events_data <- events_data %>%
  mutate(step_score = ifelse(action == "passed",
                             as.numeric(step_score_vec[step_index]), 0))

# %%
score_steps_df <- events_data %>%
  group_by(user_id) %>%
  summarise(
    total_score = sum(step_score),
    total_steps = n_distinct(step_id),
    .groups = "drop"
  )

user_level_data <- user_level_data %>%
  left_join(score_steps_df, by = "user_id")

# %%
user_level_data <- user_level_data %>%
  mutate(
    steps_per_day   = total_steps / active_days,
    score_per_day   = total_score / active_days,
    progress_percent = total_score / 88 * 100,
    steps_percent    = total_steps / 198 * 100,
    certificate      = ifelse(total_score >= 75, 1, 0),
    risk_time_threshold = last_activity + 2 * median_gap_days*24*3600
  )

# %%
end_observation <- max(
  max(events_data$timestamp_dt, na.rm = TRUE),
  max(submissions_data$timestamp_dt, na.rm = TRUE)
)

# %%
user_level_data <- user_level_data %>%
  mutate(
          drop_label = ifelse(
           certificate == 1 | risk_time_threshold > end_observation, 0,  
           1  
         ))

# %%
user_level_data %>%
    summarise(across(everything(),n_distinct)) %>%
        pivot_longer(
            cols = everything(),
            names_to = "column",
            values_to = "unique_values")
# Out:
#    column              unique_values
# 1  user_id             19234
# 2  first_activity      19223
# 3  last_activity       19226
# 4  activity_span_days   9080
# 5  active_days           121
# 6  median_gap_days       440
# 7  total_score            89
# 8  total_steps           198
# 9  steps_per_day        1993
# 10 score_per_day        1301
# 11 progress_percent       89
# 12 steps_percent         198
# 13 certificate             2
# 14 risk_time_threshold 19229
# 15 drop_label              2

# %% [markdown]
# ## EDA on Aggregated User-Level Features

# %% [markdown]
# ---

# %%
dim(user_level_data)
# Out:
# [1] 19234    15

# %%
glimpse(user_level_data)
# Out:
# Rows: 19,234
# Columns: 15
# $ user_id             <dbl> 17632, 12494, 442, 22254, 6646, 5681, 19739, 9244,…
# $ first_activity      <dttm> 2015-06-15 04:00:48, 2015-06-15 04:18:51, 2015-06…
# $ last_activity       <dttm> 2017-09-17 11:59:26, 2015-10-07 10:36:40, 2017-02…
# $ activity_span_days  <dbl> 825.332384, 114.262373, 617.739549, 26.928750, 103…
# $ active_days         <int> 20, 21, 45, 13, 14, 23, 13, 10, 22, 4, 20, 5, 32, …
# $ median_gap_days     <dbl> 1.0, 2.0, 1.0, 1.0, 5.0, 2.0, 47.0, 2.0, 2.0, 2.0,…
# $ total_score         <dbl> 34, 28, 36, 22, 83, 78, 29, 27, 31, 6, 88, 6, 81, …
# $ total_steps         <int> 119, 79, 91, 60, 186, 168, 74, 61, 71, 11, 193, 12…
# $ steps_per_day       <dbl> 5.950000, 3.761905, 2.022222, 4.615385, 13.285714,…
# $ score_per_day       <dbl> 1.7000000, 1.3333333, 0.8000000, 1.6923077, 5.9285…
# $ progress_percent    <dbl> 38.636364, 31.818182, 40.909091, 25.000000, 94.318…
# ...

# %%
summary(user_level_data)
# Out:
#     user_id      first_activity
#  Min.   :    1   Min.   :2015-06-15 04:00:48.00
#  1st Qu.: 6636   1st Qu.:2015-11-14 21:38:04.50
#  Median :13358   Median :2016-10-25 18:24:33.00
#  Mean   :13364   Mean   :2016-11-06 22:51:33.26
#  3rd Qu.:20074   3rd Qu.:2017-10-15 10:58:04.00
#  Max.   :26798   Max.   :2018-05-19 23:32:30.00
#  last_activity                    activity_span_days  active_days
#  Min.   :2015-06-15 04:54:21.00   Min.   :   1.00    Min.   :  1.00
#  1st Qu.:2016-02-29 12:23:03.75   1st Qu.:   1.00    1st Qu.:  1.00
#  Median :2017-03-03 09:44:51.00   Median :   1.00    Median :  1.00
#  Mean   :2017-01-18 18:07:26.49   Mean   :  73.31    Mean   :  6.09
#  3rd Qu.:2017-12-16 22:03:24.50   3rd Qu.:  38.40    3rd Qu.:  6.00
#  Max.   :2018-05-19 23:33:31.00   Max.   :1064.74    Max.   :478.00
#  median_gap_days     total_score     total_steps     steps_per_day
#  Min.   :   0.000   Min.   : 0.00   Min.   :  1.00   Min.   :  0.01176
# ...

# %%
colSums(is.na(user_level_data))
# Out:
#             user_id      first_activity       last_activity  activity_span_days
#                   0                   0                   0                   0
#         active_days     median_gap_days         total_score         total_steps
#                   0                   0                   0                   0
#       steps_per_day       score_per_day    progress_percent       steps_percent
#                   0                   0                   0                   0
#         certificate risk_time_threshold          drop_label
#                   0                   0                   0

# %%
sum(duplicated(user_level_data))
# Out:
# [1] 0

# %%
sum(user_level_data$first_activity > user_level_data$last_activity)
# Out:
# [1] 0

# %%
ggplot(user_level_data, aes(x = factor(drop_label))) +
  geom_bar(fill = "steelblue") +
  geom_text(stat='count', aes(label=..count..), vjust=-0.5) +
  labs(x = "Drop Label", y = "Count", title = "Distribution of Drop Label") +
  theme_minimal()
# Out:
# Warning message:
# "The dot-dot notation (`..count..`) was deprecated in ggplot2 3.4.0.
# ℹ Please use `after_stat(count)` instead."
# plot without title

# %%
user_level_data %>% count(drop_label) %>% mutate(p = n / sum(n) * 100)
# Out:
#   drop_label n     p
# 1 0           2086 10.84538
# 2 1          17148 89.15462

# %% [markdown]
# ### Классы очень несбалансированы что нужно делать:
# #Определяем веса
# #weights <- ifelse(train_data$drop_label == 0, 17148/2086, 1)
#
# # Строим логит
# #model <- glm(drop_label ~ ., data = train_data, family = binomial, weights = weights)
# #2️⃣ Следить за метриками, а не accuracy
# #Accuracy вводит в заблуждение → почти всегда ~89% без обучения.
# #Используй:ROC-AUC F1-scorePrecision / Recall
# #4️⃣ Дополнительно: предобработка признаков
# #Масштабировать числовые признаки (например, scale())
# #Категориальные → фактор / one-hot
# #Проверить выбросы и логические аномалии (что мы уже сделали)

# %%
user_level_data %>% count(certificate) %>% mutate(p = n / sum(n))
# Out:
#   certificate n     p
# 1 0           17771 0.92393678
# 2 1            1463 0.07606322

# %%
user_level_data %>%
  group_by(certificate) %>%
  summarise(
    n = n(),
    drop_rate = mean(drop_label),
    .groups = "drop"
  )
# Out:
#   certificate n     drop_rate
# 1 0           17771 0.9649429
# 2 1            1463 0.0000000

# %% [markdown]
# ### “Мы наблюдаем, что certificate сильно коррелирует с таргетом drop_label. Однако это следствие того, что drop_label формировался с использованием certificate, то есть использование этой колонки в модели приведет к утечке данных. Поэтому для построения модели certificate исключается.”

# %%
numeric_cols <- c(
  "activity_span_days",
  "active_days",
  "median_gap_days",
  "total_score",
  "total_steps",
  "steps_per_day",
  "score_per_day",
  "progress_percent",
  "steps_percent"
)

for (col_name in numeric_cols) {
  col_data <- user_level_data[[col_name]]
  
  # Решение для сильно перекошенных данных
  range_col <- max(col_data, na.rm=TRUE)/(median(col_data, na.rm=TRUE)+1e-6)
  
  if(range_col > 50) {
    # Density с log + таргет
    ggplot(user_level_data, aes(x = !!sym(col_name), fill = factor(drop_label))) +
      geom_density(alpha=0.4) +
      scale_x_log10() +
      labs(x = paste("log(", col_name, ")", sep=""),
           fill = "Drop Label",
           title = paste("Density of", col_name, "by Drop Label")) +
      theme_minimal() -> p
  } else {
    # Boxplot по таргету
    ggplot(user_level_data, aes(x = factor(drop_label), y = !!sym(col_name))) +
      geom_boxplot(outlier.alpha=0.3, fill="steelblue") +
      labs(x = "Drop Label",
           y = col_name,
           title = paste(col_name, "vs Drop Label")) +
      theme_minimal() -> p
  }
  
  print(p)
}
# Out:
# plot without title
# Warning message in scale_x_log10():
# "log-10 transformation introduced infinite values."
# Warning message:
# "Removed 9707 rows containing non-finite outside the scale range (`stat_density()`)."
# plot without title
# plot without title
# plot without title
# plot without title
# Warning message in scale_x_log10():
# "log-10 transformation introduced infinite values."
# Warning message:
# "Removed 5411 rows containing non-finite outside the scale range (`stat_density()`)."
# plot without title
# plot without title
# plot without title
# plot without title

# %%
for (col_name in numeric_cols) {
  ggplot(user_level_data, aes(x = .data[[col_name]])) +
    geom_histogram(bins = 30, fill = "steelblue", alpha = 0.6) +
    geom_density(alpha = 0.4, fill = "orange") +
    labs(
      x = col_name,
      y = "Density",
      title = paste(col_name, "Distribution")
    ) +
    theme_minimal() -> p
  
  print(p)
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
cor_matrix <- cor(user_level_data[, numeric_cols], use = "complete.obs")

# Строим тепловую карту
corrplot(cor_matrix, method = "color", type = "upper",
         addCoef.col = "black",    # добавляем числа
         tl.col = "black", tl.srt = 45, # подписи осей
         col = colorRampPalette(c("white", "steelblue"))(200),
         title = "Correlation Heatmap", mar=c(0,0,1,0))
# Out:
# Warning message in ind1:ind2:
# "у числового выражения 2 элемент(ов): использован первый"
# Plot with title "Correlation Heatmap"

# %% [markdown]
# ### “Некоторые числовые признаки сильно коррелируют между собой (r > 0.9), что объясняется тем, что они частично вычислены друг через друга. В модели мы учтём это, чтобы избежать мультиколлинеарности.”

# %%
outliers_df <- data.frame(Feature = character(),
                          Outliers = integer(),
                          Percent = numeric(),
                          stringsAsFactors = FALSE)

for (col_name in numeric_cols) {
  col_data <- user_level_data[[col_name]]
  col_data <- col_data[!is.na(col_data)]
  z_scores <- scale(col_data)
  outliers <- sum(abs(z_scores) > 3)
  percent <- round(outliers / length(col_data) * 100, 2)
  
  outliers_df <- rbind(outliers_df,
                       data.frame(Feature = col_name,
                                  Outliers = outliers,
                                  Percent = percent))
}

outliers_df
# Out:
#   Feature            Outliers Percent
# 1 activity_span_days 667      3.47
# 2 active_days        323      1.68
# 3 median_gap_days    265      1.38
# 4 total_score          0      0.00
# 5 total_steps          0      0.00
# 6 steps_per_day      272      1.41
# 7 score_per_day      255      1.33
# 8 progress_percent     0      0.00
# 9 steps_percent        0      0.00

# %% [markdown]
# ## Preprocessing for the Interpretable Model

# %%
interpretable_df <- user_level_data %>% select(
  activity_span_days,  
  active_days,         
  median_gap_days,     
  progress_percent,
  drop_label
)

# %%
numeric_cols_interpret <- setdiff(
  names(interpretable_df)[sapply(interpretable_df, is.numeric)],
  "drop_label"
)

for (col in numeric_cols_interpret) {
  p <- ggplot(interpretable_df, aes(x = .data[[col]], y = drop_label)) + 
    geom_jitter(width = 0.2, height = 0, alpha = 0.1) +  # используем jitter для бинарного таргета
    geom_smooth(method = "loess") + 
    labs(title = paste("Drop vs", col))
  
  print(p)
}
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
# plot without title

# %%
cor_matrix_interpretable <- cor(interpretable_df[, numeric_cols_interpret], use = "complete.obs")

# Строим тепловую карту
corrplot(cor_matrix_interpretable, method = "color", type = "upper",
         addCoef.col = "black",    # добавляем числа
         tl.col = "black", tl.srt = 45, # подписи осей
         col = colorRampPalette(c("white", "steelblue"))(200),
         title = "Correlation Heatmap", mar=c(0,0,1,0))
# Out:
# Warning message in ind1:ind2:
# "у числового выражения 2 элемент(ов): использован первый"
# Plot with title "Correlation Heatmap"

# %%
interpretable_df_scaled <- interpretable_df
interpretable_df_scaled[numeric_cols_interpret] <- scale(interpretable_df[numeric_cols_interpret])

# %% [markdown]
# ## PREPROCESSING BLOCK — Predictive Model (XGBoost)

# %%
predictive_df <- user_level_data %>% select(
   activity_span_days,
  active_days,
  median_gap_days,
  steps_per_day,
  score_per_day,
  progress_percent,
  steps_percent,
  drop_label
)

# %%
set.seed(123)

predictive_train_index <- caret::createDataPartition(predictive_df$drop_label, p = 0.8, list = FALSE)

predictive_train_data <- predictive_df[predictive_train_index, ]
predictive_test_data  <- predictive_df[-predictive_train_index, ]

# %%
predictive_train_x <- as.matrix(predictive_train_data[, setdiff(names(predictive_train_data), "drop_label")])
predictive_train_y <- predictive_train_data$drop_label

predictive_test_x <- as.matrix(predictive_test_data[, setdiff(names(predictive_test_data), "drop_label")])
predictive_test_y <- predictive_test_data$drop_label

# %%
scale_pos_weight <- sum(predictive_train_data$drop_label == 0) / sum(predictive_train_data$drop_label == 1)

# %% [markdown]
# ## Modeling - Interpretable Model

# %%
interpretable_full_model <- glm(
  drop_label ~ ., 
  family = binomial(link = "logit"), 
  data = interpretable_df
)

# %%
interpretable_step_model <- step(interpretable_full_model, direction = "both")
# Out:
# Start:  AIC=4711
# drop_label ~ activity_span_days + active_days + median_gap_days +
#     progress_percent
# Warning message:
# "glm.fit: возникли подогнанные вероятности 0 или 1"
#                      Df Deviance    AIC
# - active_days         1   4701.2 4709.2
# <none>                    4701.0 4711.0
# - activity_span_days  1   4706.1 4714.1
# - median_gap_days     1   6153.0 6161.0
# - progress_percent    1   9620.3 9628.3
#
# Step:  AIC=4709.22
# drop_label ~ activity_span_days + median_gap_days + progress_percent
#
#                      Df Deviance     AIC
# <none>                    4701.2  4709.2
# + active_days         1   4701.0  4711.0
# - activity_span_days  1   4707.7  4713.7
# - median_gap_days     1   6189.1  6195.1
# - progress_percent    1  10834.8 10840.8

# %%
summary(interpretable_full_model)
# Out:
# Call:
# glm(formula = drop_label ~ ., family = binomial(link = "logit"),
#     data = interpretable_df)
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.3133033  0.0842126  63.094   <2e-16 ***
# activity_span_days -0.0003974  0.0001747  -2.275   0.0229 *
# active_days        -0.0010811  0.0023193  -0.466   0.6411
# median_gap_days    -0.0260261  0.0009501 -27.393   <2e-16 ***
# progress_percent   -0.0719609  0.0013514 -53.250   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 13205  on 19233  degrees of freedom
# Residual deviance:  4701  on 19229  degrees of freedom
# AIC: 4711
#
# Number of Fisher Scoring iterations: 7

# %%
summary(interpretable_step_model)
# Out:
# Call:
# glm(formula = drop_label ~ activity_span_days + median_gap_days +
#     progress_percent, family = binomial(link = "logit"), data = interpretable_df)
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.3105737  0.0839760  63.239   <2e-16 ***
# activity_span_days -0.0004235  0.0001655  -2.559   0.0105 *
# median_gap_days    -0.0259701  0.0009419 -27.571   <2e-16 ***
# progress_percent   -0.0721441  0.0012942 -55.746   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 13204.9  on 19233  degrees of freedom
# Residual deviance:  4701.2  on 19230  degrees of freedom
# AIC: 4709.2
#
# Number of Fisher Scoring iterations: 7

# %% [markdown]
# ## Evaluation/Interpretation Interpretable Model

# %%
full_or <- exp(cbind(OR = coef(interpretable_full_model), confint(interpretable_full_model)))
# Out:
# Выполняю профилирование...

# %%
step_or <- exp(cbind(OR = coef(interpretable_step_model), confint(interpretable_step_model)))
# Out:
# Выполняю профилирование...

# %%
full_coef <- data.frame(
  Predictor = rownames(full_or),
  Full_OR = round(full_or[, "OR"], 3),
  Full_CI_Low = round(full_or[, "2.5 %"], 3),
  Full_CI_High = round(full_or[, "97.5 %"], 3),
  Full_VIF = round(c(NA, vif(interpretable_full_model)), 2)  # добавляем NA для intercept
)

# %%
step_coef <- data.frame(
  Predictor = rownames(step_or),
  Step_OR = round(step_or[, "OR"], 3),
  Step_CI_Low = round(step_or[, "2.5 %"], 3),
  Step_CI_High = round(step_or[, "97.5 %"], 3),
  Step_VIF = round(c(NA, vif(interpretable_step_model)), 2)
)

# %%
compare_df <- full_coef %>%
  full_join(step_coef, by = "Predictor") %>%
  select(Predictor, Full_OR, Full_CI_Low, Full_CI_High, Full_VIF,
         Step_OR, Step_CI_Low, Step_CI_High, Step_VIF)

# %%
kable(compare_df, caption = "Сравнение Full GLM и Stepwise GLM: Odds Ratio с 95% CI и VIF")
# Out:
# Table: Сравнение Full GLM и Stepwise GLM: Odds Ratio с 95% CI и VIF
#
# |Predictor          | Full_OR| Full_CI_Low| Full_CI_High| Full_VIF| Step_OR| Step_CI_Low| Step_CI_High| Step_VIF|
# |:------------------|-------:|-----------:|------------:|--------:|-------:|-----------:|------------:|--------:|
# |(Intercept)        | 203.020|     172.671|      240.230|       NA| 202.466|     172.279|      239.463|       NA|
# |activity_span_days |   1.000|       0.999|        1.000|     1.22|   1.000|       0.999|        1.000|     1.09|
# |active_days        |   0.999|       0.994|        1.004|     1.33|      NA|          NA|           NA|       NA|
# |median_gap_days    |   0.974|       0.972|        0.976|     1.26|   0.974|       0.973|        0.976|     1.24|
# |progress_percent   |   0.931|       0.928|        0.933|     1.39|   0.930|       0.928|        0.933|     1.27|

# %% [markdown]
# ## Modeling Predective Model

# %%
dtrain <- xgb.DMatrix(data = predictive_train_x, label = predictive_train_y)

# %%
params <- list(
  objective = "binary:logistic",
  eval_metric = "auc",
  max_depth = 6,
  eta = 0.1,
  subsample = 0.8,
  colsample_bytree = 0.8,
  scale_pos_weight = scale_pos_weight
)

# %%
cv <- xgb.cv(
  params = params,
  data = dtrain,
  nrounds = 1000,
  nfold = 5,
  early_stopping_rounds = 20,
  verbose = 1,
  maximize = TRUE
)
# Out:
# [1]	train-auc:0.973949+0.005163	test-auc:0.967656+0.007251
# Multiple eval metrics are present. Will use test_auc for early stopping.
# Will train until test_auc hasn't improved in 20 rounds.
#
# [2]	train-auc:0.978254+0.001548	test-auc:0.971269+0.004541
# [3]	train-auc:0.980239+0.001027	test-auc:0.973488+0.003139
# [4]	train-auc:0.981200+0.000715	test-auc:0.974018+0.003090
# [5]	train-auc:0.981797+0.000759	test-auc:0.974356+0.003306
# [6]	train-auc:0.982325+0.000928	test-auc:0.974087+0.003260
# [7]	train-auc:0.982856+0.000630	test-auc:0.973951+0.003413
# [8]	train-auc:0.983124+0.000673	test-auc:0.974439+0.003645
# [9]	train-auc:0.983410+0.000821	test-auc:0.974751+0.003475
# [10]	train-auc:0.983633+0.000814	test-auc:0.974513+0.003530
# [11]	train-auc:0.983824+0.000922	test-auc:0.974493+0.003591
# [12]	train-auc:0.984190+0.000992	test-auc:0.974377+0.003591
# [13]	train-auc:0.984455+0.000975	test-auc:0.974684+0.003528
# [14]	train-auc:0.984718+0.000906	test-auc:0.974766+0.003405
# ...

# %%
predictive_final_model <- xgb.train(
  params = params,
  data = dtrain,
  nrounds = cv$best_iteration
)

# %% [markdown]
# ## Evaluation/Interpretation Predictive Model

# %%
pred_prob <- predict(final_model, as.matrix(predictive_test_x))
pred_class <- ifelse(pred_prob > 0.5, 1, 0)

# %%
auc <- AUC(y_pred = pred_prob, y_true = predictive_test_y)
accuracy <- Accuracy(y_pred = pred_class, y_true = predictive_test_y)
conf_matrix <- table(Predicted = pred_class, Actual = predictive_test_y)

# %%
importance_matrix <- xgb.importance(feature_names = colnames(predictive_test_x), model = final_model)

# %%
print(paste("AUC:", round(auc, 3)))
print(paste("Accuracy:", round(accuracy, 3)))
print("Confusion Matrix:")
print(conf_matrix)
print("Feature Importance:")
print(importance_matrix)
# Out:
# [1] "AUC: 0.972"
# [1] "Accuracy: 0.96"
# [1] "Confusion Matrix:"
#          Actual
# Predicted    0    1
#         0  343   95
#         1   59 3349
# [1] "Feature Importance:"
#               Feature        Gain      Cover  Frequency
#                <char>       <num>      <num>      <num>
# 1:   progress_percent 0.355575962 0.15695912 0.07333333
# 2: activity_span_days 0.250525925 0.27601477 0.27666667
# 3:    median_gap_days 0.165102129 0.20977861 0.23333333
# 4:      steps_percent 0.122834879 0.08031201 0.07000000
# 5:        active_days 0.055734247 0.13775182 0.11666667
# 6:      score_per_day 0.042689148 0.11370181 0.13333333
# 7:      steps_per_day 0.007537711 0.02548186 0.09666667

# %%
fi <- as.data.frame(importance_matrix)
fi$Feature <- factor(fi$Feature, levels = fi$Feature[order(fi$Gain)])

# строим график
ggplot(fi, aes(x = Feature, y = Gain)) +
  geom_bar(stat = "identity", fill = "steelblue") +
  coord_flip() +
  xlab("Признак") +
  ylab("Вклад в модель (Gain)") +
  ggtitle("Feature Importance XGBoost") +
  theme_minimal(base_size = 14)
# Out:
# plot without title

# %% [markdown]
# ## общая интерпретация

# %%
glm_features <- c("activity_span_days", "median_gap_days", "progress_percent")

# Делаем датафрейм для сравнения с XGBoost
comparison <- data.frame(
  Feature = glm_features,
  GLM_OR = c(1.000, 0.974, 0.930),           # OR из Stepwise GLM
  GLM_CI_Low = c(0.999, 0.973, 0.928),
  GLM_CI_High = c(1.000, 0.976, 0.933),
  XGB_Gain = fi$Gain[match(glm_features, fi$Feature)]  # подтягиваем Gain по именам
)

print(comparison)
# Out:
#              Feature GLM_OR GLM_CI_Low GLM_CI_High  XGB_Gain
# 1 activity_span_days  1.000      0.999       1.000 0.2505259
# 2    median_gap_days  0.974      0.973       0.976 0.1651021
# 3   progress_percent  0.930      0.928       0.933 0.3555760
