# %%
if (!require(readr)) install.packages("readr")
if (!require(lubridate))install.packages("lubridate")
if (!require(dplyr)) install.packages("dplyr")
if (!require(data.table)) install.packages("data.table")
if (!require(ggplot2)) install.packages("ggplot2")
if (!require(plotly)) install.packages("plotly")
# Out:
# Загрузка требуемого пакета: plotly
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# "нет пакета под названием 'plotly'"
# пакет 'plotly' успешно распакован, MD5-суммы проверены
#
# Скачанные бинарные пакеты находятся в
# 	C:\Users\safon\AppData\Local\Temp\Rtmpq0cy5W\downloaded_packages

# %%
library(readr)
library(lubridate)
library(dplyr)
library(data.table)
library(ggplot2)
library(plotly)
# Out:
# Warning message:
# "пакет 'plotly' был собран под R версии 4.4.3"
#
# Присоединяю пакет: 'plotly'
#
#
# Следующий объект скрыт от 'package:ggplot2':
#
#     last_plot
#
#
# Следующий объект скрыт от 'package:stats':
#
#     filter
#
#
# Следующий объект скрыт от 'package:graphics':
#
#     layout

# %% [markdown]
# ## Summary:
# Purpose
#
# Data Sources (events_train, submissions_train)
#
# Metrics for step difficulty
#
# Step-level funnels
#
# Error rates & problematic tasks
#
# A table of the worst performing lessons
#
# Visualizations (heatmaps, barplots, timelines)
#
# Insights for product/design/education team

# %%
events_data <- fread("C:/Users/safon/Documents/data_stepic/event_data_train.csv")
submissions_data <- fread("C:/Users/safon/Documents/data_stepic/submissions_data_train.csv")

# %%
events_data$timestamp_dt <- as_datetime(events_data$timestamp)
submissions_data$timestamp_dt <- as_datetime(submissions_data$timestamp)

# %%
head(events_data)
# Out:
#   step_id timestamp  action     user_id timestamp_dt
# 1 32815   1434340848 viewed     17632   2015-06-15 04:00:48
# 2 32815   1434340848 passed     17632   2015-06-15 04:00:48
# 3 32815   1434340848 discovered 17632   2015-06-15 04:00:48
# 4 32811   1434340895 discovered 17632   2015-06-15 04:01:35
# 5 32811   1434340895 viewed     17632   2015-06-15 04:01:35
# 6 32811   1434340895 passed     17632   2015-06-15 04:01:35

# %%
glimpse(events_data)
# Out:
# Rows: 3,480,703
# Columns: 5
# $ step_id      <int> 32815, 32815, 32815, 32811, 32811, 32811, 32929, 32929, 3…
# $ timestamp    <int> 1434340848, 1434340848, 1434340848, 1434340895, 143434089…
# $ action       <chr> "viewed", "passed", "discovered", "discovered", "viewed",…
# $ user_id      <int> 17632, 17632, 17632, 17632, 17632, 17632, 17632, 17632, 1…
# $ timestamp_dt <dttm> 2015-06-15 04:00:48, 2015-06-15 04:00:48, 2015-06-15 04:…

# %%
events_data %>%
    summarise(across(everything(),n_distinct))
# Out:
#   step_id timestamp action user_id timestamp_dt
# 1 198     2196932   4      19234   2196932

# %%
summary(events_data)
# Out:
#     step_id         timestamp            action             user_id
#  Min.   : 30456   Min.   :1.434e+09   Length:3480703     Min.   :    1
#  1st Qu.: 32179   1st Qu.:1.450e+09   Class :character   1st Qu.: 6642
#  Median : 32929   Median :1.484e+09   Mode  :character   Median :13208
#  Mean   : 34874   Mean   :1.480e+09                      Mean   :13315
#  3rd Qu.: 33481   3rd Qu.:1.508e+09                      3rd Qu.:20144
#  Max.   :158433   Max.   :1.527e+09                      Max.   :26798
#   timestamp_dt
#  Min.   :2015-06-15 04:00:48.00
#  1st Qu.:2015-12-16 12:57:45.00
#  Median :2017-01-08 19:25:52.00
#  Mean   :2016-11-27 23:09:31.99
#  3rd Qu.:2017-10-13 10:08:22.00
#  Max.   :2018-05-19 23:33:31.00

# %%
unique(events_data$action)
# Out:
# [1] "viewed"          "passed"          "discovered"      "started_attempt"

# %%
events_data %>% count(action) %>% mutate(p = n / sum(n))
# Out:
#   action          n       p
# 1 discovered       689495 0.19809073
# 2 passed           650331 0.18683898
# 3 started_attempt  310047 0.08907597
# 4 viewed          1830830 0.52599432

# %%
colSums(is.na(events_data))
# Out:
#      step_id    timestamp       action      user_id timestamp_dt
#            0            0            0            0            0

# %%
sum(duplicated(events_data))
# Out:
# [1] 2333

# %%
head(submissions_data)
# Out:
#   step_id timestamp  submission_status user_id timestamp_dt
# 1 31971   1434349275 correct           15853   2015-06-15 06:21:15
# 2 31972   1434348300 correct           15853   2015-06-15 06:05:00
# 3 31972   1478852149 wrong             15853   2016-11-11 08:15:49
# 4 31972   1478852164 correct           15853   2016-11-11 08:16:04
# 5 31976   1434348123 wrong             15853   2015-06-15 06:02:03
# 6 31976   1434348188 correct           15853   2015-06-15 06:03:08

# %%
glimpse(submissions_data)
# Out:
# Rows: 509,104
# Columns: 5
# $ step_id           <int> 31971, 31972, 31972, 31972, 31976, 31976, 31976, 319…
# $ timestamp         <int> 1434349275, 1434348300, 1478852149, 1478852164, 1434…
# $ submission_status <chr> "correct", "correct", "wrong", "correct", "wrong", "…
# $ user_id           <int> 15853, 15853, 15853, 15853, 15853, 15853, 15853, 158…
# $ timestamp_dt      <dttm> 2015-06-15 06:21:15, 2015-06-15 06:05:00, 2016-11-1…

# %%
submissions_data %>%
    summarise(across(everything(), n_distinct))
# Out:
#   step_id timestamp submission_status user_id timestamp_dt
# 1 76      504343    2                 9940    504343

# %%
summary(submissions_data)
# Out:
#     step_id         timestamp         submission_status     user_id
#  Min.   : 31971   Min.   :1.434e+09   Length:509104      Min.   :    2
#  1st Qu.: 32031   1st Qu.:1.450e+09   Class :character   1st Qu.: 6431
#  Median : 32763   Median :1.484e+09   Mode  :character   Median :13082
#  Mean   : 33733   Mean   :1.481e+09                      Mean   :13199
#  3rd Qu.: 33481   3rd Qu.:1.508e+09                      3rd Qu.:19985
#  Max.   :120745   Max.   :1.527e+09                      Max.   :26798
#   timestamp_dt
#  Min.   :2015-06-15 04:02:24.00
#  1st Qu.:2015-12-12 19:59:30.75
#  Median :2017-01-13 20:16:27.00
#  Mean   :2016-12-01 08:53:27.83
#  3rd Qu.:2017-10-18 11:32:05.25
#  Max.   :2018-05-19 23:07:07.00

# %%
unique(submissions_data$submission_status)
# Out:
# [1] "correct" "wrong"

# %%
submissions_data %>% count(submission_status) %>% mutate(p = n / sum(n))
# Out:
#   submission_status n      p
# 1 correct           222705 0.437445
# 2 wrong             286399 0.562555

# %%
colSums(is.na(submissions_data))
# Out:
#           step_id         timestamp submission_status           user_id
#                 0                 0                 0                 0
#      timestamp_dt
#                 0

# %%
sum(duplicated(submissions_data))
# Out:
# [1] 107

# %%
events_data <- events_data[!duplicated(events_data),]
submissions_data <- submissions_data[!duplicated(submissions_data),]
sum(duplicated(events_data))
sum(duplicated(submissions_data))
# Out:
# [1] 0
# [1] 0

# %% [markdown]
# ## USER x STEP level

# %%
library(data.table)

# 1. Базовые метрики активности
user_metrics <- events_data[, .(
  n_discovered = sum(action == "discovered"),
  n_viewed = sum(action == "viewed"),
  n_started_attempt = sum(action == "started_attempt"),
  n_passed = sum(action == "passed"),
  first_timestamp = min(timestamp_dt)
), by = user_id]

# 2. Доли правильных и неправильных сабмишнов
sub_status_ratios <- submissions_data[, .(
  correct_ratio_sub = if (.N > 0) sum(submission_status == "correct") / .N else NA_real_,
  wrong_ratio_sub   = if (.N > 0) sum(submission_status == "wrong") / .N else NA_real_
), by = user_id]

# 3. Dropoff (только задания)
started <- events_data[action=="started_attempt", .(user_id, step_id)]
passed  <- events_data[action=="passed", .(user_id, step_id)]
setnames(passed, "step_id", "step_id_pass")

dropoff <- merge(started, passed, by="user_id", all.x=TRUE, allow.cartesian=TRUE)
dropoff[, drop_flag := is.na(step_id_pass)]

dropoff_user <- dropoff[, .(
  dropoff_steps = sum(drop_flag),
  first_dropoff_step = step_id[which(drop_flag)[1]]
), by = user_id]

# 4. Последняя активность пользователя (события и сабмишны)
last_event_ts <- events_data[, .(last_event_ts = max(timestamp_dt)), by=user_id]
last_submission_ts <- submissions_data[, .(last_submission_ts = max(timestamp_dt)), by=user_id]

last_ts <- merge(last_event_ts, last_submission_ts, by="user_id", all=TRUE)
last_ts[, last_timestamp := pmax(last_event_ts, last_submission_ts, na.rm=TRUE)]
last_ts <- last_ts[, .(user_id, last_timestamp)]

# 5. Объединяем все метрики
user_metrics <- merge(user_metrics, sub_status_ratios, by="user_id", all.x=TRUE)
user_metrics <- merge(user_metrics, dropoff_user, by="user_id", all.x=TRUE)
user_metrics <- merge(user_metrics, last_ts, by="user_id", all.x=TRUE)

# 6. Продолжительность курса и частота активности
user_metrics[, course_duration := as.numeric(difftime(last_timestamp, first_timestamp, units="days"))]
user_metrics[, activity_frequency := ifelse(course_duration > 0,
                                            (n_discovered + n_viewed + n_started_attempt + n_passed)/course_duration,
                                            NA_real_)]

# 7. Оставляем только нужные колонки
user_metrics <- user_metrics[, .(
  user_id,
  n_discovered, n_viewed, n_started_attempt, n_passed,
  correct_ratio_sub, wrong_ratio_sub,
  dropoff_steps, first_dropoff_step,
  course_duration, activity_frequency
)]
    
    
glimpse(user_metrics)
# Out:
# Rows: 19,234
# Columns: 11
# $ user_id            <int> 1, 2, 3, 5, 7, 8, 9, 11, 14, 16, 17, 18, 20, 22, 24…
# $ n_discovered       <int> 1, 9, 91, 11, 1, 109, 3, 1, 4, 196, 6, 3, 10, 198, …
# $ n_viewed           <int> 1, 10, 192, 12, 1, 156, 4, 1, 9, 651, 13, 3, 13, 49…
# $ n_started_attempt  <int> 0, 2, 30, 4, 0, 37, 0, 1, 1, 108, 1, 0, 0, 89, 0, 1…
# $ n_passed           <int> 0, 9, 87, 11, 1, 84, 3, 0, 3, 196, 5, 2, 8, 198, 1,…
# $ correct_ratio_sub  <dbl> NA, 1.0000000, 0.5576923, 0.5000000, NA, 0.3000000,…
# $ wrong_ratio_sub    <dbl> NA, 0.0000000, 0.4423077, 0.5000000, NA, 0.7000000,…
# $ dropoff_steps      <int> NA, 0, 0, 0, NA, 0, NA, 1, 0, 0, 0, NA, NA, 0, NA, …
# $ first_dropoff_step <int> NA, NA, NA, NA, NA, NA, NA, 31986, NA, NA, NA, NA, …
# $ course_duration    <dbl> 0.000000e+00, 5.606021e+01, 1.183231e+02, 3.900825e…
# $ activity_frequency <dbl> NA, 5.351389e-01, 3.380575e+00, 9.741528e-02, NA, 3…

# %%
actions_diagnostic <- rbindlist(lapply(c(
  "n_discovered",
  "n_viewed",
  "n_started_attempt",
  "n_passed"
), function(m) {
  x <- user_metrics[[m]]
  data.table(
    metric      = m,
    min         = min(x, na.rm = TRUE),
    p25         = quantile(x, 0.25, na.rm = TRUE),
    p50         = quantile(x, 0.50, na.rm = TRUE),
    p75         = quantile(x, 0.75, na.rm = TRUE),
    mean        = mean(x, na.rm = TRUE),
    p90         = quantile(x, 0.9,  na.rm = TRUE),
    p99         = quantile(x, 0.99, na.rm = TRUE),
    max         = max(x, na.rm = TRUE),
    pct_zero    = mean(x == 0, na.rm = TRUE),
    pct_gt_198  = mean(x > 198, na.rm = TRUE)  
  )
}))

actions_diagnostic
# Out:
#   metric            min p25 p50 p75 mean     p90   p99 max   pct_zero
# 1 n_discovered      0   1    9  42  35.84772 131.0 198   198 0.0004159301
# 2 n_viewed          0   1   12  89  95.12857 292.7 899 32778 0.0003639389
# 3 n_started_attempt 0   0    2  15  16.05703  63.0 124   721 0.4072995737
# 4 n_passed          0   1    8  39  33.81153 122.0 198   198 0.1025267755
#   pct_gt_198
# 1 0.0000000000
# 2 0.1461474472
# 3 0.0008318602
# 4 0.0000000000

# %% [markdown]
# #Вывод по активности пользователей:
#
# n_discovered и total_steps: пользователи в среднем открывают около 36 шагов, медиана 9, 75-й перцентиль 42 — распределение сдвинуто вправо из-за нескольких очень активных пользователей. Почти нет пользователей с 0 шагов, максимальные значения совпадают с общим количеством шагов (198), что соответствует логике курса.
#
# n_viewed: медиана 12, среднее 95, 75-й перцентиль 89 — видно сильный разброс, есть экстремальные значения до 32 778 просмотров, что явно аномально. 14,6% пользователей превышают количество шагов (198), что требует отдельной проверки.
#
# n_started_attempt: большинство пользователей начинают мало попыток (медиана 2, 75-й перцентиль 15), среднее выше за счёт нескольких активных пользователей. 40% пользователей вообще не начали попыток — это ожидаемо для неполных прохождений. Максимальное значение 721 — возможно аномалия.
#
# n_passed: медиана 8, 75-й перцентиль 39, среднее 34 — распределение похоже на нормальное поведение. 10% пользователей не прошли ни одного шага.
#
# Рекомендации:
#
# Проверить аномальные значения n_viewed и n_started_attempt.
#
# Использовать медиану и интерквартильный размах для оценки типичного поведения, чтобы не смущать средние значения, которые сильно искажены экстремальными пользователями.
#
# Для продуктовой диагностики достаточно этих статистик (мин, п25, п50, п75, среднее, п90/п99, макс, pct_zero, pct_gt_198).

# %%
user_metrics[n_discovered == 0 | n_viewed == 0]
# Out:
#   user_id n_discovered n_viewed n_started_attempt n_passed correct_ratio_sub
# 1  2930   0            0        7                 0        NA
# 2  3025   0            0        2                 0        NA
# 3  8251   0            2        0                 0        NA
# 4  8773   0            0        1                 0        NA
# 5 11437   0            0        1                 0        NA
# 6 13181   0            0        7                 0        NA
# 7 18842   0            0        1                 1         1
# 8 26502   0            0        1                 0        NA
#   wrong_ratio_sub dropoff_steps first_dropoff_step course_duration
# 1 NA               7            120745             0.000000000
# 2 NA               2             33992             0.000000000
# 3 NA              NA                NA             0.003275463
# 4 NA               1             32175             0.000000000
# 5 NA               1             33994             0.000000000
# ...

# %%
# хотя на первый взгляд отсутствие активности в discovered и viewed может быть подозрительным, проверка показывает что у таких пользователей 
# есть активность в других категориях и исключать их нельзя

# %%
# Рассчитываем 95%-перцентиль для нужных метрик
p95_viewed <- quantile(user_metrics$n_viewed, 0.95, na.rm = TRUE)
p95_started <- quantile(user_metrics$n_started_attempt, 0.95, na.rm = TRUE)

# Вектор пользователей с экстремальными значениями (верхние 5%)
extreme_user_ids <- user_metrics %>%
  filter(
    n_viewed > p95_viewed |
    n_started_attempt > p95_started
  ) %>%
  pull(user_id)

# Фильтруем их из датафрейма и считаем статистики без верхних 5%
actions_diagnostic_no95p <- rbindlist(lapply(c(
  "n_discovered",
  "n_viewed",
  "n_started_attempt",
  "n_passed"
), function(m) {
  x <- user_metrics[!user_id %in% extreme_user_ids, ..m][[1]]
  
  data.table(
    metric      = m,
    min         = min(x, na.rm = TRUE),
    p25         = quantile(x, 0.25, na.rm = TRUE),
    p50         = quantile(x, 0.50, na.rm = TRUE),
    p75         = quantile(x, 0.75, na.rm = TRUE),
    mean        = mean(x, na.rm = TRUE),
    p90         = quantile(x, 0.9,  na.rm = TRUE),
    p99         = quantile(x, 0.99, na.rm = TRUE),
    max         = max(x, na.rm = TRUE),
    pct_zero    = mean(x == 0, na.rm = TRUE),
    pct_gt_198  = mean(x > 198, na.rm = TRUE)
  )
}))

cat("Метрики активности пользователей с 95%-перцентилем\n")
actions_diagnostic
cat("Метрики активности пользователей без 95%-перцентиля\n")
actions_diagnostic_no95p
# Out:
# Метрики активности пользователей с 95%-перцентилем
#   metric            min p25 p50 p75 mean     p90   p99 max   pct_zero
# 1 n_discovered      0   1    9  42  35.84772 131.0 198   198 0.0004159301
# 2 n_viewed          0   1   12  89  95.12857 292.7 899 32778 0.0003639389
# 3 n_started_attempt 0   0    2  15  16.05703  63.0 124   721 0.4072995737
# 4 n_passed          0   1    8  39  33.81153 122.0 198   198 0.1025267755
#   pct_gt_198
# 1 0.0000000000
# 2 0.1461474472
# 3 0.0008318602
# 4 0.0000000000
# Метрики активности пользователей без 95%-перцентиля
#   metric            min p25 p50 p75 mean      p90   p99 max pct_zero
# 1 n_discovered      0   1    7  30  24.985645  74.0 195 198 0.0004468525
# 2 n_viewed          0   1   10  58  51.241580 172.8 395 451 0.0003909959
# 3 n_started_attempt 0   0    1  10   9.664525  33.0  87  92 0.4372451544
# 4 n_passed          0   1    6  28  23.152209  70.0 194 198 0.1101491370
#   pct_gt_198
# 1 0.00000000
# 2 0.08283528
# 3 0.00000000
# ...

# %%
#Сравнение метрик активности пользователей с верхними 5% и без них:
#1. Верхние 5% самых активных пользователей (экстремалы) сильно искажают средние и верхние перцентили, особенно для n_viewed и n_started_attempt.
#2. Исключение этих экстремалов практически не меняет медианы и нижние квартели, что подтверждает стабильность поведения основной массы пользователей.
#3. Верхние хвосты (p90, p99, max) значительно снижаются, делая статистику более репрезентативной для типичного пользователя.
#4. Доля нулевых значений (pct_zero) и доля пользователей с аномально высокой активностью (pct_gt_198) почти не меняются, что показывает, что массовое поведение остаётся неизменным.
#5. Вывод: метрики без верхних 5% дают более чистое и стабильное представление о поведении основной аудитории, в то время как полные метрики полезны для выявления суперпользователей и аномальных паттернов.

# %%
# Выбираем метрики
metrics <- c("n_discovered",
  "n_viewed",
  "n_started_attempt",
  "n_passed")

# Подготавливаем данные
plot_data <- rbindlist(lapply(metrics, function(m) {
  data.table(
    metric = m,
    value = user_metrics[[m]],
    type = "All users"
  )
}))

plot_data_no95 <- rbindlist(lapply(metrics, function(m) {
  p95 <- quantile(user_metrics[[m]], 0.95, na.rm = TRUE)
  x <- user_metrics[[m]][user_metrics[[m]] <= p95]
  data.table(
    metric = m,
    value = x,
    type = "Without top 5%"
  )
}))

plot_data <- rbind(plot_data, plot_data_no95)

# Создаем график
ggplot(plot_data, aes(x = metric, y = value, fill = type)) +
  geom_boxplot(outlier.shape = NA, alpha = 0.5, position = position_dodge(width = 0.8)) +
  geom_violin(aes(color = type), alpha = 0.2, position = position_dodge(width = 0.8), scale = "width") +
  scale_y_continuous(trans = "log10") +  # логарифмическая шкала для наглядности
  labs(
    title = "Сравнение распределения метрик активности пользователей",
    x = "Метрика",
    y = "Значение (лог10)",
    fill = "",
    color = ""
  ) +
  theme_minimal(base_size = 14) +
  theme(legend.position = "top")
# Out:
# Warning message in scale_y_continuous(trans = "log10"):
# "log-10 transformation introduced infinite values."
# Warning message in scale_y_continuous(trans = "log10"):
# "log-10 transformation introduced infinite values."
# Warning message:
# "Removed 19642 rows containing non-finite outside the scale range (`stat_boxplot()`)."
# Warning message:
# "Removed 19642 rows containing non-finite outside the scale range (`stat_ydensity()`)."
# plot without title

# %%
# Выводы по распределениям метрик активности пользователей:
# 1. Все основные метрики (n_discovered, n_viewed, n_started_attempt, n_passed)
#    имеют правостороннюю асимметрию, что типично для пользовательского поведения:
#    большинство пользователей малo- и среднеактивны, небольшая доля — сверхактивна.
# 2. Наиболее выраженный правый хвост наблюдается у n_viewed — метрика чувствительна
#    к повторным просмотрам и «скроллинговому» поведению.
# 3. Распределение n_started_attempt также правостороннее, но асимметрия заметно слабее,
#    так как начало попытки требует осознанного действия пользователя.
# 4. Исключение верхних 5% самых активных пользователей существенно сокращает хвосты
#    и снижает влияние выбросов на средние и верхние перцентили.
# 5. При этом медианы и межквартильный размах почти не меняются, что подтверждает
#    устойчивость и репрезентативность поведения основной массы пользователей.
# 6. Вывод: для продуктовой диагностики и сравнения пользователей целесообразно
#    использовать метрики без верхних 5%, сохраняя полное распределение отдельно
#    для анализа суперпользователей и аномального поведения.

# %%
user_metrics[, is_extreme := user_id %in% extreme_user_ids]

# %%
user_metrics %>% count(dropoff_steps) %>% mutate(p = n / sum(n) * 100)
# Out:
#   dropoff_steps n     p
# 1  0            10688 55.568264532
# 2  1              665  3.457419154
# 3  2               34  0.176770303
# 4  3                9  0.046792139
# 5  4                1  0.005199127
# 6  5                1  0.005199127
# 7  7                2  0.010398253
# 8 NA             7834 40.729957367

# %%
# Вывод по распределению dropoff_steps:
# 1. Большинство пользователей, которые начали практические задания, проходят все начатые шаги:
#    dropoff_steps = 0 → 10 688 пользователей (~55,6%).
# 2. Значительная часть пользователей не приступает к практическим заданиям вообще:
#    dropoff_steps = NA → 7 834 пользователей (~40,7%). 
#    Основная задача продукта — повысить вовлеченность на старте практики.
# 3. Пользователи, которые бросают отдельные шаги (dropoff_steps = 1–7), составляют очень малую долю (~4%), 
#    при этом почти нет пользователей, которые бросают много шагов подряд.
# 4. Редкие значения >5 можно рассматривать индивидуально, но они не влияют на общую картину.
# 5. Продуктовый инсайт: курс и задания в целом корректны и проходимы, 
#    основная проблема — мотивация пользователей начать практические шаги.

# %% [markdown]
# ## STEP_LEVEL

# %%
length(setdiff(
  events_data$step_id,
  submissions_data$step_id
))
# Out:
# [1] 122

# %%
length(setdiff(
  submissions_data$step_id,
  events_data$step_id
))
# Out:
# [1] 0

# %%
steps <- sort(unique(events_data$step_id))
step_score_vec <- rep(0, length(steps))

score <- list(
  `1` = c(3,14,15,18,19,22,30,31,32,33,38,39,40,47,49,53,54,55,56,57,
          62,64,65,68,73,74,76,80,81,82,83,95,100,104,108,109,111,
          122,123,131,133,138,139,140,141,147,148,149,155,156,157,
          161,162,163,169,170,172,177,185,186),

  `2` = c(41,63,94,99,113,114,115,125,132,179,189),

  `3` = c(126,180)
)

# Векторизация загрузки score
step_score_vec[unlist(score)] <- rep(names(score), lengths(score))

steps_table <- data.table(
  step_id = steps,
  step_score = step_score_vec
)

steps_table[, is_assignment := step_id %in% submissions_data$step_id]

## было сравнение с ноутбуком с ML, присвоение скор прошло корректно
colnames(steps_table)
# Out:
# [1] "step_id"       "step_score"    "is_assignment"

# %%
# ===========================
# 1. Функция расчета метрик по шагам
# ===========================
compute_steps_metrics_dt <- function(steps_table, events_dt, submissions_dt, filter_extreme = NULL, type_label = "all") {
  
  dt_events <- copy(events_dt)
  dt_subs <- copy(submissions_dt)
  steps_dt <- copy(steps_table)
  
  # Фильтруем пользователей по флагу
  if (!is.null(filter_extreme)) {
    dt_events <- dt_events[is_extreme %in% filter_extreme]
    dt_subs <- dt_subs[user_id %in% dt_events$user_id]
  }
  
  # Считаем количество уникальных пользователей по действию
  counts <- dt_events[action %in% c("viewed","started_attempt","passed"), 
                      .(N = uniqueN(user_id)), 
                      by = .(step_id, action)]
  
  counts_wide <- dcast(counts, step_id ~ action, value.var = "N", fill = 0)
  setnames(counts_wide, c("viewed","started_attempt","passed"), c("n_users_viewed","n_started_attempt","n_passed"))
  
  steps_dt <- merge(steps_dt, counts_wide, by = "step_id", all.x = TRUE)
  
  # Заполняем NA нулями
  for (col in c("n_users_viewed","n_started_attempt","n_passed")) {
    steps_dt[is.na(get(col)), (col) := 0L]
  }
  
  # Конверсии
  steps_dt[, start_rate := fifelse(n_users_viewed > 0, n_started_attempt / n_users_viewed, NA_real_)]
  steps_dt[, pass_rate  := fifelse(n_started_attempt > 0, n_passed / n_started_attempt, NA_real_)]
  steps_dt[, dropoff_rate := 1 - pass_rate]
  
  # Сабмишны
  subs_metrics <- dt_subs[, .(
    pass_rate_submissions = mean(submission_status == "correct", na.rm = TRUE)
  ), by = step_id]
  
  steps_dt <- merge(steps_dt, subs_metrics, by = "step_id", all.x = TRUE)
  
  steps_dt[, data_type := type_label]
  
  return(steps_dt)
}

# ===========================
# 2. Генерация трех таблиц
# ===========================
steps_all      <- compute_steps_metrics_dt(steps_table, events_data, submissions_data, NULL, "all")
steps_no_ext   <- compute_steps_metrics_dt(steps_table, events_data, submissions_data, filter_extreme = FALSE, "no_extremes")
steps_only_ext <- compute_steps_metrics_dt(steps_table, events_data, submissions_data, filter_extreme = TRUE, "only_extremes")

# Объединяем все таблицы
steps_combined <- rbindlist(list(steps_all, steps_no_ext, steps_only_ext), fill = TRUE)

# ===========================
# 3. Статистика с префиксами в широком формате
# ===========================
step_metrics <- c("n_users_viewed","n_started_attempt","n_passed",
                  "start_rate","pass_rate","dropoff_rate","pass_rate_submissions")

prefix_map <- c(
  all = "_all",
  no_extremes = "_no_ext",
  only_extremes = "_ext"
)

# Для каждой метрики и типа считаем mean, median, p90
stats_list <- lapply(step_metrics, function(m) {
  dt <- data.table(metric = m)
  for (dt_type in names(prefix_map)) {
    pref <- prefix_map[[dt_type]]
    steps_tmp <- steps_combined[data_type == dt_type]
    
    dt[, paste0("mean", pref)   := round(mean(steps_tmp[[m]], na.rm = TRUE), 2)]
    dt[, paste0("median", pref) := round(median(steps_tmp[[m]], na.rm = TRUE), 2)]
    dt[, paste0("p90", pref)    := round(quantile(steps_tmp[[m]], 0.9, na.rm = TRUE), 2)]
  }
  dt
})

stats_combined_wide <- rbindlist(stats_list)
stats_combined_wide
# Out:
#   metric                mean_all median_all p90_all mean_no_ext median_no_ext
# 1 n_users_viewed        3483.92  2538.50    6763.80 2259.64     1290.00
# 2 n_started_attempt     1196.01     0.00    3729.90  731.81        0.00
# 3 n_passed              3284.50  2395.00    6445.90 2093.40     1166.00
# 4 start_rate               0.35     0.00       0.94    0.33        0.00
# 5 pass_rate                0.91     0.92       0.95    0.86        0.86
# 6 dropoff_rate             0.09     0.08       0.14    0.14        0.14
# 7 pass_rate_submissions    0.49     0.47       0.72    0.56        0.58
#   p90_no_ext mean_ext median_ext p90_ext
# 1 5447.60    1224.28  1256.50    1321.30
# 2 2431.10     464.20     0.00    1296.30
# 3 5135.60    1191.10  1223.50    1312.00
# 4    0.92       0.37     0.00       0.99
# 5    0.93       0.96     0.96       0.99
# 6    0.21       0.04     0.04       0.09
# 7    0.79       0.47     0.45       0.72

# %% [markdown]
# # Аналитический вывод по метрикам шагов
#
# ## 1. Объем активности пользователей (count metrics)
#
# - **n_users_viewed**
#   - Среднее (all) = 3484, медиана = 2539, p90 = 6764
#   - Без экстремальных пользователей: среднее = 2260, медиана = 1290, p90 = 5448
#   - Только экстремальные пользователи: среднее = 1224, медиана = 1257, p90 = 1321
#   **Вывод:** экстремальные пользователи создают сильный верхний хвост; основная масса просматривает меньше шагов.
#
# - **n_started_attempt**
#   - Медиана = 0 во всех группах
#   - Средние значения: all = 1196, no_ext = 732, ext = 464
#   **Вывод:** основная проблема — низкий старт попытки, экстремальные пользователи сильно влияют на средние.
#
# - **n_passed**
#   - Средние и p90 зависят от экстремальных пользователей
#   - Медианы без экстремумов показывают меньший проход шагов обычными пользователями
#   **Вывод:** успешное прохождение высокое, экстремальные пользователи “тянут” средние значения.
#
# ## 2. Конверсии и drop-off (rate metrics)
#
# - **start_rate**
#   - Медиана = 0, p90 = 0.92–0.99
#   **Вывод:** бимодальное распределение; большинство шагов начинают немногие, лишь часть шагов — почти все.
#
# - **pass_rate**
#   - Высокие значения для всех групп: all = 0.91, no_ext = 0.86, ext = 0.96
#   **Вывод:** шаги в целом не сложные; экстремальные пользователи слегка повышают среднее.
#
# - **dropoff_rate**
#   - Соответствует pass_rate; медиана = 0.08–0.14, p90 = 0.09–0.21
#   **Вывод:** отвал выше у обычных пользователей, экстремальные почти всегда завершают шаги.
#
# - **pass_rate_submissions**
#   - Среднее: all = 0.49, no_ext = 0.56, ext = 0.47
#   **Вывод:** обычные пользователи делают меньше ошибок по сабмишнам, активные пользователи совершают больше попыток и часть неверная.
#
# ## 3. Общие выводы
#
# 1. Экстремальные пользователи малочисленны, но сильно влияют на средние показатели.
# 2. Основной узкий момент — низкий старт попытки (start_rate).
# 3. Высокий pass_rate при низком start_rate указывает, что сложность шагов не является проблемой.
# 4. Для диагностики пользовательских проблем корректнее ориентироваться на показатели без экстремальных пользователей.

# %%
library(data.table)
library(ggplot2)

# --- Объёмные метрики ---
count_metrics <- c("n_users_viewed", "n_started_attempt", "n_passed")

plot_data_counts <- melt(
  steps_combined,
  id.vars = c("step_id", "step_score", "is_assignment", "data_type"),
  measure.vars = count_metrics,
  variable.name = "metric",
  value.name = "value"
)

ggplot(plot_data_counts, aes(x = metric, y = value, fill = data_type)) +
  geom_boxplot(outlier.shape = NA, alpha = 0.5, position = position_dodge(width = 0.8)) +
  geom_violin(aes(color = data_type), alpha = 0.2, position = position_dodge(width = 0.8), scale = "width") +
  scale_y_continuous(trans = "log10") +
  scale_x_discrete(expand = expansion(add = 0.8)) +
  labs(
    title = "Активность пользователей на шагах (объёмы)",
    x = "Метрика",
    y = "Значение (лог10)",
    fill = "",
    color = ""
  ) +
  theme_minimal(base_size = 14) +
  theme(
    axis.text.x = element_text(angle = 25, hjust = 1),
    legend.position = "top",
    panel.grid.major.x = element_blank(),
    panel.grid.minor.x = element_blank()
  )
# Out:
# Warning message in scale_y_continuous(trans = "log10"):
# "log-10 transformation introduced infinite values."
# Warning message in scale_y_continuous(trans = "log10"):
# "log-10 transformation introduced infinite values."
# Warning message:
# "Removed 366 rows containing non-finite outside the scale range (`stat_boxplot()`)."
# Warning message:
# "Removed 366 rows containing non-finite outside the scale range (`stat_ydensity()`)."
# plot without title

# %%
# --- Объёмные метрики ---
count_metrics <- c("n_users_viewed", "n_started_attempt", "n_passed")

plot_data_counts <- melt(
  steps_combined,
  id.vars = c("step_id", "step_score", "is_assignment", "data_type"),
  measure.vars = count_metrics,
  variable.name = "metric",
  value.name = "value"
)

ggplot(plot_data_counts, aes(x = metric, y = value, fill = data_type)) +
  geom_boxplot(outlier.shape = NA, alpha = 0.5, position = position_dodge(width = 0.8)) +
  geom_violin(aes(color = data_type), alpha = 0.2, position = position_dodge(width = 0.8), scale = "width") +
  scale_y_continuous(trans = "log10") +
  scale_x_discrete(expand = expansion(add = 0.8)) +
  labs(
    title = "Активность пользователей на шагах (объёмы)",
    x = "Метрика",
    y = "Значение (лог10)",
    fill = "",
    color = ""
  ) +
  theme_minimal(base_size = 14) +
  theme(
    axis.text.x = element_text(angle = 25, hjust = 1),
    legend.position = "top",
    panel.grid.major.x = element_blank(),
    panel.grid.minor.x = element_blank()
  )
# Out:
# Warning message in scale_y_continuous(trans = "log10"):
# "log-10 transformation introduced infinite values."
# Warning message in scale_y_continuous(trans = "log10"):
# "log-10 transformation introduced infinite values."
# Warning message:
# "Removed 366 rows containing non-finite outside the scale range (`stat_boxplot()`)."
# Warning message:
# "Removed 366 rows containing non-finite outside the scale range (`stat_ydensity()`)."
# plot without title
